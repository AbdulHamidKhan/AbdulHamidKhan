# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulHamidKhan/AbdulHamidKhan/blob/main/ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10

# %%
name= "Abdullah"
age=25
weight=85.5
print(age)
# Out:
# 25

# %%
fruits=['ma','no','go']
print(fruits[0])
for i in fruits:
    print(i)
# Out:
# ma
# ma
# no
# go

# %%
age=18
if age==17:
  print("you are eligible")
else:
  print("you are not eligible")
# Out:
# you are not eligible

# %%
#Function
def greet(name):
  print("hello",name)

#function calling
greet("abdullah")
# Out:
# hello abdullah

# %% [markdown]
# # **NUMPY**

# %%
import numpy as np

# %%
arr1=np.array([[1,2,3],[4,5,6]])
print(arr1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
for row in arr1.flat:
  print(row)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# # **pandas**

# %%
import pandas as pd

# %%
data = {
  "name":["shi"],
  "age": ["fg"],
  "city":["f"]
}

# %%
print(data)
# Out:
# {'name': ['shi'], 'age': ['fg'], 'city': ['f']}

# %%
import pandas as pd
pd.DataFrame(data)
# Out:
#   name age city
# 0  shi  fg    f

# %%
df=pd.read_csv("/content/httpschatgpt.txt")
df
# Out:
# Empty DataFrame
# Columns: [https://chatgpt.com/s/t_6924701299648191aeae02cdef36a00e]
# Index: []

# %% [markdown]
# # **matplot**

# %%
x=[1,2,3,4]
y=[10,28,30,40]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.title('line plot')
plt.xlabel('x axix')
plt.ylabel('y axis')
plt.title('plot')
plt.show()
